# %% [markdown]
# # Make a reference database in FASTA format for an IPG Query

# %%
# Import packages
from Bio import Entrez
from Bio import SeqIO


# Set email adress
Entrez.email = "remi.legrand38@gmail.com.com"

# %% [markdown]
# ## 1. Gather ID of IPG reports from a QUERY (2 sec)

# %%
# Function to search data on NCBI
def search_id(query, number_seq):
    handle = Entrez.esearch(db="ipg", term=query,
                            retmax=number_seq)  # number of sequences
    record = Entrez.read(handle)
    handle.close()
    return record["IdList"]

# %%
# Create a list containing the ID
query = "((nifH[Gene Name]) AND 100:350[Sequence Length]) NOT uncultured"
seq_id = search_id(query, 20000)
print(seq_id)
# len(seq_id)
# Out:
# ['15644230', '15422654', '469614905', '463335738', '463307954', '463296292', '461244997', '461241703', '446901641', '427477591', '427469729', '427466342', '427423626', '415604000', '350848217', '350787255', '349442739', '349436496', '299156976', '226445887', '194947467', '180173506', '180172798', '180171254', '180170887', '100437320', '71845111', '69701369', '69700817', '69697418', '63695862', '56757924', '52011023', '44394908', '39093004', '36733349', '32474742', '22048464', '6622016', '6145268', '885911', '436307', '173295', '364405625', '353120723', '350866440', '350778347', '350773083', '349936002', '349903660', '349902885', '349841539', '349838987', '349837590', '349811669', '349694507', '347358025', '326797342', '304648145', '294032489', '279337086', '274656235', '224994493', '214571543', '214571338', '204648154', '202205411', '202148507', '202146568', '202099735', '123537395', '122931342', '110709219', '109359436', '92962718', '53228297', '42037040', '39031999', '19703386', '19703379', '544258602', '477063836', '272806088', '270837483', '264978530', '264947017', '264884675', '264871923', '264571125', '264554433', '264549284', '262436636', '262435916', '262432296', '259511239', '239865460', '220604531', '219331445', '212545514', '212539371', '200502038', '197808711', '197803721', '190375111', '190371540', '190370860', '189161703', '188853370', '188848583', '184670326', '153556742', '147355920', '135337371', '133118696', '120660404', '118566395', '77100295', '73111106', '55473691', '49064160', '38900993', '24742219', '1357689', '176119227', '162947156', '161825058', '161736949', '153009463', '143853963', '135935847', '135836538', '135772817', '130705237', '130652119', '130142936', '129736997', '127974850', '127971653', '127920796', '127920778', '127919708', '127919546', '127779902', '127648120', '127531281', '127322638', '127125494', '127122484', '127087507', '127062695', '127017415', '126356117', '126304867', '126304579', '126303933', '126282539', '126269699', '126268211', '126034968', '125941120', '124881648', '124866631', '124765227', '124720317', '124669500', '124605006', '123866180', '123700428', '123699430', '123666075', '123575349', '123564615', '123365806', '123246407', '123240796', '123239312', '123238946', '123238896', '123238747', '123238302', '123046695', '122968996', '122968989', '41802272', '40163719', '6304299', '651109310', '651099322', '539807534', '427539919', '427349194', '427347870', '427347502', '427307658', '123485017', '120090222', '108730382', '77311835', '77141912', '75522125', '75003110', '68375739', '56229910', '55856836', '55125244', '46203031', '44492778', '41802330', '41801635', '32423034', '32005358', '32004869', '31938024', '20398129', '18484032', '15572256', '14673592', '12961247', '5376840', '4854056', '4567662', '4491880', '4342778', '3945456', '1463069', '1035279', '1033916', '870966', '866525', '846574', '838938', '810119', '479494', '444818', '407815', '306911', '296546', '214464', '131216', '107895', '94880', '427352784', '427352231', '427323180', '427300029', '427299397', '349975272', '328571347', '319883179', '319881941', '240261437', '238099139', '227006154', '200599404', '199647670', '195996521', '195508867', '195498420', '178280531', '159366625', '152984701', '152983676', '152982965', '152982650', '152982176', '148510676', '72843271', '71766791', '55527035', '55464749', '53781794', '52404005', '42741177', '27789054', '27315039', '27314643', '26701466', '26032789', '25428097', '23508923', '23507715', '23505988', '23437708', '23278482', '23276971', '22405568', '21516054', '21322064', '21235429', '19764320', '17770359', '6912556', '6762936', '6761288', '4835960', '4835842', '418950', '427265305', '318572539', '173317869', '159033970', '139300988', '130622989', '118024775', '76681546', '58291763', '58285484', '48364865', '28202610', '24992349', '641239620', '427232246', '427231683', '427214518', '427214206', '427189007', '426227741', '342204281', '312306347', '310624662', '138479444 ...

# %% [markdown]
# ## 2. Download the IPG report (92 min)

# %%
def ipg_report(ipg_accession):
    # Use the efetch function to retrieve the IPG record in XML format
    handle = Entrez.efetch(db="ipg", id=ipg_accession,
                           rettype="ipg", retmode="text")
    ipg_record = handle.read()

    # Save the IPG record to a file
    filename = f"ipg_report/ipg_{ipg_accession}.txt"
    with open(filename, "wb") as file:
        file.write(ipg_record)

    print(f"IPG record saved to '{filename}'")

# %%
for id in seq_id:
    ipg_report(id)
    # print(id)
# ipg_report('127919708')
# Out:
# IPG record saved to 'ipg_report/ipg_15644230.txt'
# IPG record saved to 'ipg_report/ipg_15422654.txt'
# IPG record saved to 'ipg_report/ipg_469614905.txt'
# IPG record saved to 'ipg_report/ipg_463335738.txt'
# IPG record saved to 'ipg_report/ipg_463307954.txt'
# IPG record saved to 'ipg_report/ipg_463296292.txt'
# IPG record saved to 'ipg_report/ipg_461244997.txt'
# IPG record saved to 'ipg_report/ipg_461241703.txt'
# IPG record saved to 'ipg_report/ipg_446901641.txt'
# IPG record saved to 'ipg_report/ipg_427477591.txt'
# IPG record saved to 'ipg_report/ipg_427469729.txt'
# IPG record saved to 'ipg_report/ipg_427466342.txt'
# IPG record saved to 'ipg_report/ipg_427423626.txt'
# IPG record saved to 'ipg_report/ipg_415604000.txt'
# IPG record saved to 'ipg_report/ipg_350848217.txt'
# IPG record saved to 'ipg_report/ipg_350787255.txt'
# IPG record saved to 'ipg_report/ipg_349442739.txt'
# IPG record saved to 'ipg_report/ipg_349436496.txt'
# IPG record saved to 'ipg_report/ipg_299156976.txt'
# IPG record saved to 'ipg_report/ipg_226445887.txt'
# IPG record saved to 'ipg_report/ipg_194947467.txt'
# IPG record saved to 'ipg_report/ipg_180173506.txt'
# IPG record saved to 'ipg_report/ipg_180172798.txt'
# IPG record saved to 'ipg_report/ipg_180171254.txt'
# IPG record saved to 'ipg_report/ipg_180170887.txt'
# IPG record saved to 'ipg_report/ipg_100437320.txt'
# IPG record saved to 'ipg_report/ipg_71845111.txt'
# IPG record saved to 'ipg_report/ipg_69701369.txt'
# IPG record saved to 'ipg_report/ipg_69700817.txt'
# IPG record saved to 'ipg_report/ipg_69697418.txt'
# IPG record saved to 'ipg_report/ipg_63695862.txt'
# IPG record saved to 'ipg_report/ipg_56757924.txt'
# IPG record saved to 'ipg_report/ipg_52011023.txt'
# IPG record saved to 'ipg_report/ipg_44394908.txt'
# IPG record saved to 'ipg_report/ipg_39093004.txt'
# IPG record saved to 'ipg_report/ipg_36733349.txt'
# IPG record saved to 'ipg_report/ipg_32474742.txt'
# IPG record saved to 'ipg_report/ipg_22048464.txt'
# IPG record saved to 'ipg_report/ipg_6622016.txt'
# IPG record saved to 'ipg_report/ipg_6145268.txt'
# IPG record saved to 'ipg_report/ipg_885911.txt'
# IPG record saved to 'ipg_report/ipg_436307.txt'
# IPG record saved to 'ipg_report/ipg_173295.txt'
# IPG record saved to 'ipg_report/ipg_364405625.txt'
# IPG record saved to 'ipg_report/ipg_353120723.txt'
# IPG record saved to 'ipg_report/ipg_350866440.txt'
# IPG record saved to 'ipg_report/ipg_350778347.txt'
# IPG record saved to 'ipg_report/ipg_350773083.txt'
# IPG record saved to 'ipg_report/ipg_349936002.txt'
# IPG record saved to 'ipg_report/ipg_349903660.txt'
# IPG record saved to 'ipg_report/ipg_349902885.txt'
# IPG record saved to 'ipg_report/ipg_349841539.txt'
# IPG record saved to 'ipg_report/ipg_349838987.txt'
# IPG record saved to 'ipg_report/ipg_349837590.txt'
# IPG record saved to 'ipg_report/ipg_349811669.txt'
# IPG record saved to 'ipg_report/ipg_349694507.txt'
# IPG record saved to 'ipg_report/ipg_347358025.txt'
# IPG record saved to 'ipg_report/ipg_326797342.txt'
# IPG record saved to 'ipg_report/ipg_304648145.txt'
# IPG record saved to 'ipg_report/ipg_294032489.txt'
# IPG record saved to 'ipg_report/ipg_279337086.txt'
# IPG record saved to 'ipg_report/ipg_274656235.txt'
# IPG record saved to 'ipg_report/ipg_224994493.txt'
# IPG record saved to 'ipg_report/ipg_214571543.txt'
# IPG record saved to 'ipg_report/ipg_214571338.txt'
# IPG record saved to 'ipg_report/ipg_204648154.txt'
# IPG record saved to 'ipg_report/ipg_202205411.txt'
# IPG record saved to 'ipg_report/ipg_202148507.txt'
# IPG record saved to 'ipg_report/ipg_202146568.txt'
# IPG record saved to 'ipg_report/ipg_202099735.txt'
# IPG record saved to 'ipg_report/ipg_123537395.txt'
# IPG record saved to 'ipg_report/ipg_122931342.txt'
# IPG record saved to 'ipg_report/ipg_110709219.txt'
# IPG record saved to 'ipg_report/ipg_109359436.txt'
# IPG record saved to 'ipg_report/ipg_92962718.txt'
# IPG record saved to 'ipg_report/ipg_53228297.txt'
# IPG record saved to 'ipg_report/ipg_42037040.txt'
# IPG record saved to 'ipg_report/ipg_39031999.txt'
# IPG record saved to 'ipg_report/ipg_19703386.txt'
# IPG record saved to 'ipg_report/ipg_19703379.txt'
# IPG record saved to 'ipg_report/ipg_544258602.txt'
# IPG record saved to 'ipg_report/ipg_477063836.txt'
# IPG record saved to 'ipg_report/ipg_272806088.txt'
# IPG record saved to 'ipg_report/ipg_270837483.txt'
# IPG record saved to 'ipg_report/ipg_264978530.txt'
# IPG record saved to 'ipg_report/ipg_264947017.txt'
# IPG record saved to 'ipg_report/ipg_264884675.txt'
# IPG record saved to 'ipg_report/ipg_264871923.txt'
# IPG record saved to 'ipg_report/ipg_264571125.txt'
# IPG record saved to 'ipg_report/ipg_264554433.txt'
# IPG record saved to 'ipg_report/ipg_264549284.txt'
# IPG record saved to 'ipg_report/ipg_262436636.txt'
# IPG record saved to 'ipg_report/ipg_262435916.txt'
# IPG record saved to 'ipg_report/ipg_262432296.txt'
# IPG record saved to 'ipg_report/ipg_259511239.txt'
# IPG record saved to 'ipg_report/ipg_239865460.txt'
# IPG record saved to 'ipg_report/ipg_220604531.txt'
# IPG record saved to 'ipg_report/ipg_219331445.txt'
# IPG record saved to 'ipg_report/ipg_212545514.txt'
# IPG record saved to 'ipg_report/ipg_212539371.txt'
# IPG record saved to 'ipg_report/ipg_200502038.txt'
# IPG record saved to 'ipg_report/ipg_197808711.txt'
# IPG record saved to 'ipg_report/ipg_197803721.txt'
# IPG record saved to 'ipg_report/ipg_190375111.txt'
# IPG record saved to 'ipg_report/ipg_190371540.txt'
# IPG record saved to 'ipg_report/ipg_190370860.txt'
# IPG record saved to 'ipg_report/ipg_189161703.txt'
# IPG record saved to 'ipg_report/ipg_188853370.txt'
# IPG record saved to 'ipg_report/ipg_188848583.txt'
# IPG record saved to 'ipg_report/ipg_184670326.txt'
# IPG record saved to 'ipg_report/ipg_153556742.txt'
# IPG record saved to 'ipg_report/ipg_147355920.txt'
# IPG record saved to 'ipg_report/ipg_135337371.txt'
# IPG record saved to 'ipg_report/ipg_133118696.txt'
# IPG record saved to 'ipg_report/ipg_120660404.txt'
# IPG record saved to 'ipg_report/ipg_118566395.txt'
# IPG record saved to 'ipg_report/ipg_77100295.txt'
# IPG record saved to 'ipg_report/ipg_73111106.txt'
# IPG record saved to 'ipg_report/ipg_55473691.txt'
# IPG record saved to 'ipg_report/ipg_49064160.txt'
# IPG record saved to 'ipg_report/ipg_38900993.txt'
# IPG record saved to 'ipg_report/ipg_24742219.txt'
# IPG record saved to 'ipg_report/ipg_1357689.txt'
# IPG record saved to 'ipg_report/ipg_176119227.txt'
# IPG record saved to 'ipg_report/ipg_162947156.txt'
# IPG record saved to 'ipg_report/ipg_161825058.txt'
# IPG record saved to 'ipg_report/ipg_161736949.txt'
# IPG record saved to 'ipg_report/ipg_153009463.txt'
# IPG record saved to 'ipg_report/ipg_143853963.txt'
# IPG record saved to 'ipg_report/ipg_135935847.txt'
# IPG record saved to 'ipg_report/ipg_135836538.txt'
# IPG record saved to 'ipg_report/ipg_135772817.txt'
# IPG record saved to 'ipg_report/ipg_130705237.txt'
# IPG record saved to 'ipg_report/ipg_130652119.txt'
# IPG record saved to 'ipg_report/ipg_130142936.txt'
# IPG record saved to 'ipg_report/ipg_129736997.txt'
# IPG record saved to 'ipg_report/ipg_127974850.txt'
# IPG record saved to 'ipg_report/ipg_127971653.txt'
# IPG record saved to 'ipg_report/ipg_127920796.txt'
# IPG record saved to 'ipg_report/ipg_127920778.txt'
# IPG record saved to 'ipg_report/ipg_127919708.txt'
# IPG record saved to 'ipg_report/ipg_127919546.txt'
# IPG record saved to 'ipg_report/ipg_127779902.txt'
# IPG record saved to 'ipg_report/ipg_127648120.txt'
# IPG record saved to 'ipg_report/ipg_127531281.txt'
# IPG record saved to 'ipg_report/ipg_127322638.txt'
# IPG record saved to 'ipg_report/ipg_127125494.txt'
# IPG record saved to 'ipg_report/ipg_127122484.txt'
# IPG record saved to 'ipg_report/ipg_127087507.txt'
# IPG record saved to 'ipg_report/ipg_127062695.txt'
# IPG record saved to 'ipg_report/ipg_127017415.txt'
# IPG record saved to 'ipg_report/ipg_126356117.txt'
# IPG record saved to 'ipg_report/ipg_126304867.txt'
# IPG record saved to 'ipg_report/ipg_126304579.txt'
# IPG record saved to 'ipg_report/ipg_126303933.txt'
# IPG record saved to 'ipg_report/ipg_126282539.txt'
# IPG record saved to 'ipg_report/ipg_126269699.txt'
# IPG record saved to 'ipg_report/ipg_126268211.txt'
# IPG record saved to 'ipg_report/ipg_126034968.txt'
# IPG record saved to 'ipg_report/ipg_125941120.txt'
# IPG record saved to 'ipg_report/ipg_124881648.txt'
# IPG record saved to 'ipg_report/ipg_124866631.txt'
# IPG record saved to 'ipg_report/ipg_124765227.txt'
# IPG record saved to 'ipg_report/ipg_124720317.txt'
# IPG record saved to 'ipg_report/ipg_124669500.txt'
# IPG record saved to 'ipg_report/ipg_124605006.txt'
# IPG record saved to 'ipg_report/ipg_123866180.txt'
# IPG record saved to 'ipg_report/ipg_123700428.txt'
# IPG record saved to 'ipg_report/ipg_123699430.txt'
# IPG record saved to 'ipg_report/ipg_123666075.txt'
# IPG record saved to 'ipg_report/ipg_123575349.txt'
# IPG record saved to 'ipg_report/ipg_123564615.txt'
# IPG record saved to 'ipg_report/ipg_123365806.txt'
# IPG record saved to 'ipg_report/ipg_123246407.txt'
# IPG record saved to 'ipg_report/ipg_123240796.txt'
# IPG record saved to 'ipg_report/ipg_123239312.txt'
# IPG record saved to 'ipg_report/ipg_123238946.txt'
# IPG record saved to 'ipg_report/ipg_123238896.txt'
# IPG record saved to 'ipg_report/ipg_123238747.txt'
# IPG record saved to 'ipg_report/ipg_123238302.txt'
# IPG record saved to 'ipg_report/ipg_123046695.txt'
# IPG record saved to 'ipg_report/ipg_122968996.txt'
# IPG record saved to 'ipg_report/ipg_122968989.txt'
# IPG record saved to 'ipg_report/ipg_41802272.txt'
# IPG record saved to 'ipg_report/ipg_40163719.txt'
# IPG record saved to 'ipg_report/ipg_6304299.txt'
# IPG record saved to 'ipg_report/ipg_651109310.txt'
# IPG record saved to 'ipg_report/ipg_651099322.txt'
# IPG record saved to 'ipg_report/ipg_539807534.txt'
# IPG record saved to 'ipg_report/ipg_427539919.txt'
# IPG record saved to 'ipg_report/ipg_427349194.txt'
# IPG record saved to 'ipg_report/ipg_427347870.txt'
# IPG record saved to 'ipg_report/ipg_427347502.txt'
# IPG record saved to 'ipg_report/ipg_427307658.txt'
# IPG record saved to 'ipg_report/ipg_123485017.txt'
# IPG record saved to 'ipg_report/ipg_120090222.txt'
# IPG record saved to 'ipg_report/ipg_108730382.txt'
# IPG record saved to 'ipg_report/ipg_77311835.txt'
# IPG record saved to 'ipg_report/ipg_77141912.txt'
# IPG record saved to 'ipg_report/ipg_75522125.txt'
# IPG record saved to 'ipg_report/ipg_75003110.txt'
# IPG record saved to 'ipg_report/ipg_68375739.txt'
# IPG record saved to 'ipg_report/ipg_56229910.txt'
# IPG record saved to 'ipg_report/ipg_55856836.txt'
# IPG record saved to 'ipg_report/ipg_55125244.txt'
# IPG record saved to 'ipg_report/ipg_46203031.txt'
# IPG record saved to 'ipg_report/ipg_44492778.txt'
# IPG record saved to 'ipg_report/ipg_41802330.txt'
# IPG record saved to 'ipg_report/ipg_41801635.txt'
# IPG record saved to 'ipg_report/ipg_32423034.txt'
# IPG record saved to 'ipg_report/ipg_32005358.txt'
# IPG record saved to 'ipg_report/ipg_32004869.txt'
# IPG record saved to 'ipg_report/ipg_31938024.txt'
# IPG record saved to 'ipg_report/ipg_20398129.txt'
# IPG record saved to 'ipg_report/ipg_18484032.txt'
# IPG record saved to 'ipg_report/ipg_15572256.txt'
# IPG record saved to 'ipg_report/ipg_14673592.txt'
# IPG record saved to 'ipg_report/ipg_12961247.txt'
# IPG record saved to 'ipg_report/ipg_5376840.txt'
# IPG record saved to 'ipg_report/ipg_4854056.txt'
# IPG record saved to 'ipg_report/ipg_4567662.txt'
# IPG record saved to 'ipg_report/ipg_4491880.txt'
# IPG record saved to 'ipg_report/ipg_4342778.txt'
# IPG record saved to 'ipg_report/ipg_3945456.txt'
# IPG record saved to 'ipg_report/ipg_1463069.txt'
# IPG record saved to 'ipg_report/ipg_1035279.txt'
# IPG record saved to 'ipg_report/ipg_1033916.txt'
# IPG record saved to 'ipg_report/ipg_870966.txt'
# IPG record saved to 'ipg_report/ipg_866525.txt'
# IPG record saved to 'ipg_report/ipg_846574.txt'
# IPG record saved to 'ipg_report/ipg_838938.txt'
# IPG record saved to 'ipg_report/ipg_810119.txt'
# IPG record saved to 'ipg_report/ipg_479494.txt'
# IPG record saved to 'ipg_report/ipg_444818.txt'
# IPG record saved to 'ipg_report/ipg_407815.txt'
# IPG record saved to 'ipg_report/ipg_306911.txt'
# IPG record saved to 'ipg_report/ipg_296546.txt'
# IPG record saved to 'ipg_report/ipg_214464.txt'
# IPG record saved to 'ipg_report/ipg_131216.txt'
# IPG record saved to 'ipg_report/ipg_107895.txt'
# IPG record saved to 'ipg_report/ipg_94880.txt'
# IPG record saved to 'ipg_report/ipg_427352784.txt'
# IPG record saved to 'ipg_report/ipg_427352231.txt'
# IPG record saved to 'ipg_report/ipg_427323180.txt'
# IPG record saved to 'ipg_report/ipg_427300029.txt'
# IPG record saved to 'ipg_report/ipg_427299397.txt'
# IPG record saved to 'ipg_report/ipg_349975272.txt'
# IPG record saved to 'ipg_report/ipg_328571347.txt'
# IPG record saved to 'ipg_report/ipg_319883179.txt'
# IPG record saved to 'ipg_report/ipg_319881941.txt'
# IPG record saved to 'ipg_report/ipg_240261437.txt'
# IPG record saved to 'ipg_report/ipg_238099139.txt'
# IPG record saved to 'ipg_report/ipg_227006154.txt'
# IPG record saved to 'ipg_report/ipg_200599404.txt'
# IPG record saved to 'ipg_report/ipg_199647670.txt'
# IPG record saved to 'ipg_report/ipg_195996521.txt'
# IPG record saved to 'ipg_report/ipg_195508867.txt'
# IPG record saved to 'ipg_report/ipg_195498420.txt'
# IPG record saved to 'ipg_report/ipg_178280531.txt'
# IPG record saved to 'ipg_report/ipg_159366625.txt'
# IPG record saved to 'ipg_report/ipg_152984701.txt'
# IPG record saved to 'ipg_report/ipg_152983676.txt'
# IPG record saved to 'ipg_report/ipg_152982965.txt'
# IPG record saved to 'ipg_report/ipg_152982650.txt'
# IPG record saved to 'ipg_report/ipg_152982176.txt'
# IPG record saved to 'ipg_report/ipg_148510676.txt'
# IPG record saved to 'ipg_report/ipg_72843271.txt'
# IPG record saved to 'ipg_report/ipg_71766791.txt'
# IPG record saved to 'ipg_report/ipg_55527035.txt'
# IPG record saved to 'ipg_report/ipg_55464749.txt'
# IPG record saved to 'ipg_report/ipg_53781794.txt'
# IPG record saved to 'ipg_report/ipg_52404005.txt'
# IPG record saved to 'ipg_report/ipg_42741177.txt'
# IPG record saved to 'ipg_report/ipg_27789054.txt'
# IPG record saved to 'ipg_report/ipg_27315039.txt'
# IPG record saved to 'ipg_report/ipg_27314643.txt'
# IPG record saved to 'ipg_report/ipg_26701466.txt'
# IPG record saved to 'ipg_report/ipg_26032789.txt'
# IPG record saved to 'ipg_report/ipg_25428097.txt'
# IPG record saved to 'ipg_report/ipg_23508923.txt'
# IPG record saved to 'ipg_report/ipg_23507715.txt'
# IPG record saved to 'ipg_report/ipg_23505988.txt'
# IPG record saved to 'ipg_report/ipg_23437708.txt'
# IPG record saved to 'ipg_report/ipg_23278482.txt'
# IPG record saved to 'ipg_report/ipg_23276971.txt'
# IPG record saved to 'ipg_report/ipg_22405568.txt'
# IPG record saved to 'ipg_report/ipg_21516054.txt'
# IPG record saved to 'ipg_report/ipg_21322064.txt'
# IPG record saved to 'ipg_report/ipg_21235429.txt'
# IPG record saved to 'ipg_report/ipg_19764320.txt'
# IPG record saved to 'ipg_report/ipg_17770359.txt'
# IPG record saved to 'ipg_report/ipg_6912556.txt'
# IPG record saved to 'ipg_report/ipg_6762936.txt'
# IPG record saved to 'ipg_report/ipg_6761288.txt'
# IPG record saved to 'ipg_report/ipg_4835960.txt'
# IPG record saved to 'ipg_report/ipg_4835842.txt'
# IPG record saved to 'ipg_report/ipg_418950.txt'
# IPG record saved to 'ipg_report/ipg_427265305.txt'
# IPG record saved to 'ipg_report/ipg_318572539.txt'
# IPG record saved to 'ipg_report/ipg_173317869.txt'
# IPG record saved to 'ipg_report/ipg_159033970.txt'
# IPG record saved to 'ipg_report/ipg_139300988.txt'
# IPG record saved to 'ipg_report/ipg_130622989.txt'
# IPG record saved to 'ipg_report/ipg_118024775.txt'
# IPG record saved to 'ipg_report/ipg_76681546.txt'
# IPG record saved to 'ipg_report/ipg_58291763.txt'
# IPG record saved to 'ipg_report/ipg_58285484.txt'
# IPG record saved to 'ipg_report/ipg_48364865.txt'
# IPG record saved to 'ipg_report/ipg_28202610.txt'
# IPG record saved to 'ipg_report/ipg_24992349.txt'
# IPG record saved to 'ipg_report/ipg_641239620.txt'
# IPG record saved to 'ipg_report/ipg_427232246.txt'
# IPG record saved to 'ipg_report/ipg_427231683.txt'
# IPG record saved to 'ipg_report/ipg_427214518.txt'
# IPG record saved to 'ipg_report/ipg_427214206.txt'
# IPG record saved to 'ipg_report/ipg_427189007.txt'
# IPG record saved to 'ipg_report/ipg_426227741.txt'
# IPG record saved to 'ipg_report/ipg_342204281.txt'
# IPG record saved to 'ipg_report/ipg_312306347.txt'
# IPG record saved to 'ipg_report/ipg_310624662.txt'
# IPG record saved to 'ipg_report/ipg_138479444.txt'
# IPG record saved to 'ipg_report/ipg_116969386.txt'
# IPG record saved to 'ipg_report/ipg_101517144.txt'
# IPG record saved to 'ipg_report/ipg_54025438.txt'
# IPG record saved to 'ipg_report/ipg_46437436.txt'
# IPG record saved to 'ipg_report/ipg_42345012.txt'
# IPG record saved to 'ipg_report/ipg_42344936.txt'
# IPG record saved to 'ipg_report/ipg_26379150.txt'
# IPG record saved to 'ipg_report/ipg_19266767.txt'
# IPG record saved to 'ipg_report/ipg_463259952.txt'
# IPG record saved to 'ipg_report/ipg_463259714.txt'
# IPG record saved to 'ipg_report/ipg_416073695.txt'
# IPG record saved to 'ipg_report/ipg_93010728.txt'
# IPG record saved to 'ipg_report/ipg_14637244.txt'
# IPG record saved to 'ipg_report/ipg_1847537.txt'
# IPG record saved to 'ipg_report/ipg_463197251.txt'
# IPG record saved to 'ipg_report/ipg_291390783.txt'
# IPG record saved to 'ipg_report/ipg_288000386.txt'
# IPG record saved to 'ipg_report/ipg_237796490.txt'
# IPG record saved to 'ipg_report/ipg_204803915.txt'
# IPG record saved to 'ipg_report/ipg_198580063.txt'
# IPG record saved to 'ipg_report/ipg_197880151.txt'
# IPG record saved to 'ipg_report/ipg_195542792.txt'
# IPG record saved to 'ipg_report/ipg_195541741.txt'
# IPG record saved to 'ipg_report/ipg_185314362.txt'
# IPG record saved to 'ipg_report/ipg_184601172.txt'
# IPG record saved to 'ipg_report/ipg_184224296.txt'
# IPG record saved to 'ipg_report/ipg_177187587.txt'
# IPG record saved to 'ipg_report/ipg_171855570.txt'
# IPG record saved to 'ipg_report/ipg_139286659.txt'
# IPG record saved to 'ipg_report/ipg_127558258.txt'
# IPG record saved to 'ipg_report/ipg_127140665.txt'
# IPG record saved to 'ipg_report/ipg_127022915.txt'
# IPG record saved to 'ipg_report/ipg_124553667.txt'
# IPG record saved to 'ipg_report/ipg_117450949.txt'
# IPG record saved to 'ipg_report/ipg_61856521.txt'
# IPG record saved to 'ipg_report/ipg_38370565.txt'
# IPG record saved to 'ipg_report/ipg_22198965.txt'
# IPG record saved to 'ipg_report/ipg_85443429.txt'
# IPG record saved to 'ipg_report/ipg_85442718.txt'
# IPG record saved to 'ipg_report/ipg_32036992.txt'
# IPG record saved to 'ipg_report/ipg_25498901.txt'
# IPG record saved to 'ipg_report/ipg_5359549.txt'
# IPG record saved to 'ipg_report/ipg_271356377.txt'
# IPG record saved to 'ipg_report/ipg_217762715.txt'
# IPG record saved to 'ipg_report/ipg_135885652.txt'
# IPG record saved to 'ipg_report/ipg_135883123.txt'
# IPG record saved to 'ipg_report/ipg_130945239.txt'
# IPG record saved to 'ipg_report/ipg_71832337.txt'
# IPG record saved to 'ipg_report/ipg_17987213.txt'
# IPG record saved to 'ipg_report/ipg_17987200.txt'
# IPG record saved to 'ipg_report/ipg_542019072.txt'
# IPG record saved to 'ipg_report/ipg_127874364.txt'
# IPG record saved to 'ipg_report/ipg_127838789.txt'
# IPG record saved to 'ipg_report/ipg_127836347.txt'
# IPG record saved to 'ipg_report/ipg_127477437.txt'
# IPG record saved to 'ipg_report/ipg_126406520.txt'
# IPG record saved to 'ipg_report/ipg_126345434.txt'
# IPG record saved to 'ipg_report/ipg_125781713.txt'
# IPG record saved to 'ipg_report/ipg_125780973.txt'
# IPG record saved to 'ipg_report/ipg_125780315.txt'
# IPG record saved to 'ipg_report/ipg_125779233.txt'
# IPG record saved to 'ipg_report/ipg_124958140.txt'
# IPG record saved to 'ipg_report/ipg_102594480.txt'
# IPG record saved to 'ipg_report/ipg_76686504.txt'
# IPG record saved to 'ipg_report/ipg_57430919.txt'
# IPG record saved to 'ipg_report/ipg_42505774.txt'
# IPG record saved to 'ipg_report/ipg_38057986.txt'
# IPG record saved to 'ipg_report/ipg_127799907.txt'
# IPG record saved to 'ipg_report/ipg_123148115.txt'
# IPG record saved to 'ipg_report/ipg_91176004.txt'
# IPG record saved to 'ipg_report/ipg_72039072.txt'
# IPG record saved to 'ipg_report/ipg_51561885.txt'
# IPG record saved to 'ipg_report/ipg_34584062.txt'
# IPG record saved to 'ipg_report/ipg_24992348.txt'
# IPG record saved to 'ipg_report/ipg_19682041.txt'
# IPG record saved to 'ipg_report/ipg_19682034.txt'
# IPG record saved to 'ipg_report/ipg_974741.txt'
# IPG record saved to 'ipg_report/ipg_187108560.txt'
# IPG record saved to 'ipg_report/ipg_159402100.txt'
# IPG record saved to 'ipg_report/ipg_139281800.txt'
# IPG record saved to 'ipg_report/ipg_139281622.txt'
# IPG record saved to 'ipg_report/ipg_139281062.txt'
# IPG record saved to 'ipg_report/ipg_139281046.txt'
# IPG record saved to 'ipg_report/ipg_130829682.txt'
# IPG record saved to 'ipg_report/ipg_127552941.txt'
# IPG record saved to 'ipg_report/ipg_126699944.txt'
# IPG record saved to 'ipg_report/ipg_126387706.txt'
# IPG record saved to 'ipg_report/ipg_125274103.txt'
# IPG record saved to 'ipg_report/ipg_62682570.txt'
# IPG record saved to 'ipg_report/ipg_46830664.txt'
# IPG record saved to 'ipg_report/ipg_45607494.txt'
# IPG record saved to 'ipg_report/ipg_44194117.txt'
# IPG record saved to 'ipg_report/ipg_26851522.txt'
# IPG record saved to 'ipg_report/ipg_123080886.txt'
# IPG record saved to 'ipg_report/ipg_114456868.txt'
# IPG record saved to 'ipg_report/ipg_113564356.txt'
# IPG record saved to 'ipg_report/ipg_329268044.txt'
# IPG record saved to 'ipg_report/ipg_329267539.txt'
# IPG record saved to 'ipg_report/ipg_329265591.txt'
# IPG record saved to 'ipg_report/ipg_329265040.txt'
# IPG record saved to 'ipg_report/ipg_329246928.txt'
# IPG record saved to 'ipg_report/ipg_329246839.txt'
# IPG record saved to 'ipg_report/ipg_241426833.txt'
# IPG record saved to 'ipg_report/ipg_202063129.txt'
# IPG record saved to 'ipg_report/ipg_35416621.txt'
# IPG record saved to 'ipg_report/ipg_19230318.txt'
# IPG record saved to 'ipg_report/ipg_3333551.txt'
# IPG record saved to 'ipg_report/ipg_329205532.txt'
# IPG record saved to 'ipg_report/ipg_329201828.txt'
# IPG record saved to 'ipg_report/ipg_329170350.txt'
# IPG record saved to 'ipg_report/ipg_309153697.txt'
# IPG record saved to 'ipg_report/ipg_309091654.txt'
# IPG record saved to 'ipg_report/ipg_308959938.txt'
# IPG record saved to 'ipg_report/ipg_308958276.txt'
# IPG record saved to 'ipg_report/ipg_308957336.txt'
# IPG record saved to 'ipg_report/ipg_291260110.txt'
# IPG record saved to 'ipg_report/ipg_240471132.txt'
# IPG record saved to 'ipg_report/ipg_240185986.txt'
# IPG record saved to 'ipg_report/ipg_202484257.txt'
# IPG record saved to 'ipg_report/ipg_202357460.txt'
# IPG record saved to 'ipg_report/ipg_202303895.txt'
# IPG record saved to 'ipg_report/ipg_193673244.txt'
# IPG record saved to 'ipg_report/ipg_104278607.txt'
# IPG record saved to 'ipg_report/ipg_93012361.txt'
# IPG record saved to 'ipg_report/ipg_71839511.txt'
# IPG record saved to 'ipg_report/ipg_41824784.txt'
# IPG record saved to 'ipg_report/ipg_41824775.txt'
# IPG record saved to 'ipg_report/ipg_13295431.txt'
# IPG record saved to 'ipg_report/ipg_13295294.txt'
# IPG record saved to 'ipg_report/ipg_13089628.txt'
# IPG record saved to 'ipg_report/ipg_541072870.txt'
# IPG record saved to 'ipg_report/ipg_240069306.txt'
# IPG record saved to 'ipg_report/ipg_239956490.txt'
# IPG record saved to 'ipg_report/ipg_239147491.txt'
# IPG record saved to 'ipg_report/ipg_237822638.txt'
# IPG record saved to 'ipg_report/ipg_237805199.txt'
# IPG record saved to 'ipg_report/ipg_237784776.txt'
# IPG record saved to 'ipg_report/ipg_237537181.txt'
# IPG record saved to 'ipg_report/ipg_237534645.txt'
# IPG record saved to 'ipg_report/ipg_217413207.txt'
# IPG record saved to 'ipg_report/ipg_185525703.txt'
# IPG record saved to 'ipg_report/ipg_540549211.txt'
# IPG record saved to 'ipg_report/ipg_540546277.txt'
# IPG record saved to 'ipg_report/ipg_238135303.txt'
# IPG record saved to 'ipg_report/ipg_238068781.txt'
# IPG record saved to 'ipg_report/ipg_238033945.txt'
# IPG record saved to 'ipg_report/ipg_238033728.txt'
# IPG record saved to 'ipg_report/ipg_238011033.txt'
# IPG record saved to 'ipg_report/ipg_237753160.txt'
# IPG record saved to 'ipg_report/ipg_237631717.txt'
# IPG record saved to 'ipg_report/ipg_237558790.txt'
# IPG record saved to 'ipg_report/ipg_237556228.txt'
# IPG record saved to 'ipg_report/ipg_237546561.txt'
# IPG record saved to 'ipg_report/ipg_237545788.txt'
# IPG record saved to 'ipg_report/ipg_237543566.txt'
# IPG record saved to 'ipg_report/ipg_236836286.txt'
# IPG record saved to 'ipg_report/ipg_175078968.txt'
# IPG record saved to 'ipg_report/ipg_118346356.txt'
# IPG record saved to 'ipg_report/ipg_93734039.txt'
# IPG record saved to 'ipg_report/ipg_80127487.txt'
# IPG record saved to 'ipg_report/ipg_78878895.txt'
# IPG record saved to 'ipg_report/ipg_38503589.txt'
# IPG record saved to 'ipg_report/ipg_38361446.txt'
# IPG record saved to 'ipg_report/ipg_38361411.txt'
# IPG record saved to 'ipg_report/ipg_6026621.txt'
# IPG record saved to 'ipg_report/ipg_987416.txt'
# IPG record saved to 'ipg_report/ipg_645425935.txt'
# IPG record saved to 'ipg_report/ipg_539685976.txt'
# IPG record saved to 'ipg_report/ipg_539671057.txt'
# IPG record saved to 'ipg_report/ipg_419589625.txt'
# IPG record saved to 'ipg_report/ipg_419587926.txt'
# IPG record saved to 'ipg_report/ipg_419587133.txt'
# IPG record saved to 'ipg_report/ipg_419558010.txt'
# IPG record saved to 'ipg_report/ipg_397753938.txt'
# IPG record saved to 'ipg_report/ipg_377136294.txt'
# IPG record saved to 'ipg_report/ipg_377132739.txt'
# IPG record saved to 'ipg_report/ipg_377101746.txt'
# IPG record saved to 'ipg_report/ipg_377074296.txt'
# IPG record saved to 'ipg_report/ipg_377066729.txt'
# IPG record saved to 'ipg_report/ipg_377063811.txt'
# IPG record saved to 'ipg_report/ipg_375330677.txt'
# IPG record saved to 'ipg_report/ipg_375258499.txt'
# IPG record saved to 'ipg_report/ipg_375185107.txt'
# IPG record saved to 'ipg_report/ipg_375163347.txt'
# IPG record saved to 'ipg_report/ipg_375160890.txt'
# IPG record saved to 'ipg_report/ipg_375129317.txt'
# IPG record saved to 'ipg_report/ipg_375129261.txt'
# IPG record saved to 'ipg_report/ipg_375092709.txt'
# IPG record saved to 'ipg_report/ipg_375067733.txt'
# IPG record saved to 'ipg_report/ipg_375066715.txt'
# IPG record saved to 'ipg_report/ipg_375047821.txt'
# IPG record saved to 'ipg_report/ipg_374907072.txt'
# IPG record saved to 'ipg_report/ipg_374873647.txt'
# IPG record saved to 'ipg_report/ipg_374872394.txt'
# IPG record saved to 'ipg_report/ipg_374830548.txt'
# IPG record saved to 'ipg_report/ipg_374748709.txt'
# IPG record saved to 'ipg_report/ipg_374746810.txt'
# IPG record saved to 'ipg_report/ipg_363531674.txt'
# IPG record saved to 'ipg_report/ipg_353844176.txt'
# IPG record saved to 'ipg_report/ipg_335644168.txt'
# IPG record saved to 'ipg_report/ipg_329192741.txt'
# IPG record saved to 'ipg_report/ipg_329191214.txt'
# IPG record saved to 'ipg_report/ipg_285605951.txt'
# IPG record saved to 'ipg_report/ipg_282006447.txt'
# IPG record saved to 'ipg_report/ipg_281769116.txt'
# IPG record saved to 'ipg_report/ipg_280476822.txt'
# IPG record saved to 'ipg_report/ipg_253028280.txt'
# IPG record saved to 'ipg_report/ipg_206731762.txt'
# IPG record saved to 'ipg_report/ipg_206626680.txt'
# IPG record saved to 'ipg_report/ipg_204670904.txt'
# IPG record saved to 'ipg_report/ipg_204325297.txt'
# IPG record saved to 'ipg_report/ipg_202308283.txt'
# IPG record saved to 'ipg_report/ipg_155756134.txt'
# IPG record saved to 'ipg_report/ipg_134154147.txt'
# IPG record saved to 'ipg_report/ipg_126569627.txt'
# IPG record saved to 'ipg_report/ipg_113614661.txt'
# IPG record saved to 'ipg_report/ipg_93036118.txt'
# IPG record saved to 'ipg_report/ipg_93036113.txt'
# IPG record saved to 'ipg_report/ipg_56094218.txt'
# IPG record saved to 'ipg_report/ipg_53571220.txt'
# IPG record saved to 'ipg_report/ipg_41653051.txt'
# IPG record saved to 'ipg_report/ipg_41584191.txt'
# IPG record saved to 'ipg_report/ipg_33837878.txt'
# IPG record saved to 'ipg_report/ipg_33837731.txt'
# IPG record saved to 'ipg_report/ipg_26279359.txt'
# IPG record saved to 'ipg_report/ipg_19927604.txt'
# IPG record saved to 'ipg_report/ipg_19927596.txt'
# IPG record saved to 'ipg_report/ipg_17625147.txt'
# IPG record saved to 'ipg_report/ipg_16944330.txt'
# IPG record saved to 'ipg_report/ipg_16761134.txt'
# IPG record saved to 'ipg_report/ipg_14527338.txt'
# IPG record saved to 'ipg_report/ipg_13883636.txt'
# IPG record saved to 'ipg_report/ipg_13448186.txt'
# IPG record saved to 'ipg_report/ipg_377153922.txt'
# IPG record saved to 'ipg_report/ipg_377077154.txt'
# IPG record saved to 'ipg_report/ipg_40926432.txt'
# IPG record saved to 'ipg_report/ipg_539631561.txt'
# IPG record saved to 'ipg_report/ipg_539631559.txt'
# IPG record saved to 'ipg_report/ipg_539626812.txt'
# IPG record saved to 'ipg_report/ipg_363586383.txt'
# IPG record saved to 'ipg_report/ipg_363053979.txt'
# IPG record saved to 'ipg_report/ipg_353617677.txt'
# IPG record saved to 'ipg_report/ipg_353119534.txt'
# IPG record saved to 'ipg_report/ipg_353119488.txt'
# IPG record saved to 'ipg_report/ipg_347143057.txt'
# IPG record saved to 'ipg_report/ipg_343900609.txt'
# IPG record saved to 'ipg_report/ipg_335923451.txt'
# IPG record saved to 'ipg_report/ipg_331543499.txt'
# IPG record saved to 'ipg_report/ipg_301027324.txt'
# IPG record saved to 'ipg_report/ipg_300999494.txt'
# IPG record saved to 'ipg_report/ipg_300985075.txt'
# IPG record saved to 'ipg_report/ipg_300967562.txt'
# IPG record saved to 'ipg_report/ipg_300947723.txt'
# IPG record saved to 'ipg_report/ipg_300932500.txt'
# IPG record saved to 'ipg_report/ipg_292508633.txt'
# IPG record saved to 'ipg_report/ipg_291343165.txt'
# IPG record saved to 'ipg_report/ipg_291342379.txt'
# IPG record saved to 'ipg_report/ipg_269647024.txt'
# IPG record saved to 'ipg_report/ipg_269629323.txt'
# IPG record saved to 'ipg_report/ipg_269628369.txt'
# IPG record saved to 'ipg_report/ipg_268531706.txt'
# IPG record saved to 'ipg_report/ipg_232341889.txt'
# IPG record saved to 'ipg_report/ipg_232326656.txt'
# IPG record saved to 'ipg_report/ipg_202309567.txt'
# IPG record saved to 'ipg_report/ipg_202193804.txt'
# IPG record saved to 'ipg_report/ipg_183531423.txt'
# IPG record saved to 'ipg_report/ipg_140669911.txt'
# IPG record saved to 'ipg_report/ipg_130527701.txt'
# IPG record saved to 'ipg_report/ipg_120617285.txt'
# IPG record saved to 'ipg_report/ipg_93012355.txt'
# IPG record saved to 'ipg_report/ipg_91652501.txt'
# IPG record saved to 'ipg_report/ipg_80471961.txt'
# IPG record saved to 'ipg_report/ipg_80449785.txt'
# IPG record saved to 'ipg_report/ipg_71912841.txt'
# IPG record saved to 'ipg_report/ipg_71806463.txt'
# IPG record saved to 'ipg_report/ipg_71803935.txt'
# IPG record saved to 'ipg_report/ipg_71803398.txt'
# IPG record saved to 'ipg_report/ipg_45820355.txt'
# IPG record saved to 'ipg_report/ipg_43789057.txt'
# IPG record saved to 'ipg_report/ipg_42037048.txt'
# IPG record saved to 'ipg_report/ipg_26384674.txt'
# IPG record saved to 'ipg_report/ipg_19925304.txt'
# IPG record saved to 'ipg_report/ipg_14939321.txt'
# IPG record saved to 'ipg_report/ipg_5011332.txt'
# IPG record saved to 'ipg_report/ipg_645353972.txt'
# IPG record saved to 'ipg_report/ipg_645184628.txt'
# IPG record saved to 'ipg_report/ipg_645174401.txt'
# IPG record saved to 'ipg_report/ipg_645138677.txt'
# IPG record saved to 'ipg_report/ipg_645133700.txt'
# IPG record saved to 'ipg_report/ipg_645069078.txt'
# IPG record saved to 'ipg_report/ipg_644961987.txt'
# IPG record saved to 'ipg_report/ipg_644935390.txt'
# IPG record saved to 'ipg_report/ipg_644899042.txt'
# IPG record saved to 'ipg_report/ipg_644895427.txt'
# IPG record saved to 'ipg_report/ipg_644881169.txt'
# IPG record saved to 'ipg_report/ipg_592790323.txt'
# IPG record saved to 'ipg_report/ipg_592789806.txt'
# IPG record saved to 'ipg_report/ipg_566904656.txt'
# IPG record saved to 'ipg_report/ipg_539540636.txt'
# IPG record saved to 'ipg_report/ipg_539537257.txt'
# IPG record saved to 'ipg_report/ipg_537711065.txt'
# IPG record saved to 'ipg_report/ipg_523793720.txt'
# IPG record saved to 'ipg_report/ipg_521591041.txt'
# IPG record saved to 'ipg_report/ipg_500188336.txt'
# IPG record saved to 'ipg_report/ipg_497366194.txt'
# IPG record saved to 'ipg_report/ipg_488570648.txt'
# IPG record saved to 'ipg_report/ipg_454448625.txt'
# IPG record saved to 'ipg_report/ipg_452943489.txt'
# IPG record saved to 'ipg_report/ipg_452725001.txt'
# IPG record saved to 'ipg_report/ipg_452677126.txt'
# IPG record saved to 'ipg_report/ipg_452483279.txt'
# IPG record saved to 'ipg_report/ipg_411537858.txt'
# IPG record saved to 'ipg_report/ipg_282255406.txt'
# IPG record saved to 'ipg_report/ipg_281118835.txt'
# IPG record saved to 'ipg_report/ipg_280035669.txt'
# IPG record saved to 'ipg_report/ipg_274626408.txt'
# IPG record saved to 'ipg_report/ipg_273288882.txt'
# IPG record saved to 'ipg_report/ipg_271171493.txt'
# IPG record saved to 'ipg_report/ipg_271169461.txt'
# IPG record saved to 'ipg_report/ipg_268498709.txt'
# IPG record saved to 'ipg_report/ipg_262331504.txt'
# IPG record saved to 'ipg_report/ipg_260276710.txt'
# IPG record saved to 'ipg_report/ipg_260164100.txt'
# IPG record saved to 'ipg_report/ipg_260164097.txt'
# IPG record saved to 'ipg_report/ipg_260160278.txt'
# IPG record saved to 'ipg_report/ipg_260160272.txt'
# IPG record saved to 'ipg_report/ipg_260159010.txt'
# IPG record saved to 'ipg_report/ipg_260154941.txt'
# IPG record saved to 'ipg_report/ipg_253051158.txt'
# IPG record saved to 'ipg_report/ipg_253041312.txt'
# IPG record saved to 'ipg_report/ipg_251478865.txt'
# IPG record saved to 'ipg_report/ipg_238065022.txt'
# IPG record saved to 'ipg_report/ipg_238064922.txt'
# IPG record saved to 'ipg_report/ipg_237855404.txt'
# IPG record saved to 'ipg_report/ipg_237825849.txt'
# IPG record saved to 'ipg_report/ipg_237526532.txt'
# IPG record saved to 'ipg_report/ipg_237526437.txt'
# IPG record saved to 'ipg_report/ipg_232331521.txt'
# IPG record saved to 'ipg_report/ipg_232319033.txt'
# IPG record saved to 'ipg_report/ipg_230711820.txt'
# IPG record saved to 'ipg_report/ipg_227829959.txt'
# IPG record saved to 'ipg_report/ipg_227829941.txt'
# IPG record saved to 'ipg_report/ipg_218233313.txt'
# IPG record saved to 'ipg_report/ipg_218231400.txt'
# IPG record saved to 'ipg_report/ipg_218231251.txt'
# IPG record saved to 'ipg_report/ipg_217584068.txt'
# IPG record saved to 'ipg_report/ipg_217584066.txt'
# IPG record saved to 'ipg_report/ipg_210835451.txt'
# IPG record saved to 'ipg_report/ipg_210835436.txt'
# IPG record saved to 'ipg_report/ipg_205438652.txt'
# IPG record saved to 'ipg_report/ipg_204706495.txt'
# IPG record saved to 'ipg_report/ipg_204706457.txt'
# IPG record saved to 'ipg_report/ipg_204692472.txt'
# IPG record saved to 'ipg_report/ipg_204646895.txt'
# IPG record saved to 'ipg_report/ipg_204616728.txt'
# IPG record saved to 'ipg_report/ipg_204616716.txt'
# IPG record saved to 'ipg_report/ipg_204593438.txt'
# IPG record saved to 'ipg_report/ipg_204558818.txt'
# IPG record saved to 'ipg_report/ipg_204555327.txt'
# IPG record saved to 'ipg_report/ipg_204555298.txt'
# IPG record saved to 'ipg_report/ipg_204487607.txt'
# IPG record saved to 'ipg_report/ipg_204479316.txt'
# IPG record saved to 'ipg_report/ipg_204468455.txt'
# IPG record saved to 'ipg_report/ipg_204468392.txt'
# IPG record saved to 'ipg_report/ipg_204467297.txt'
# IPG record saved to 'ipg_report/ipg_204467284.txt'
# IPG record saved to 'ipg_report/ipg_204463934.txt'
# IPG record saved to 'ipg_report/ipg_204463927.txt'
# IPG record saved to 'ipg_report/ipg_204455636.txt'
# IPG record saved to 'ipg_report/ipg_204455590.txt'
# IPG record saved to 'ipg_report/ipg_204388658.txt'
# IPG record saved to 'ipg_report/ipg_204383470.txt'
# IPG record saved to 'ipg_report/ipg_204356471.txt'
# IPG record saved to 'ipg_report/ipg_204346202.txt'
# IPG record saved to 'ipg_report/ipg_204044290.txt'
# IPG record saved to 'ipg_report/ipg_203989152.txt'
# IPG record saved to 'ipg_report/ipg_202484263.txt'
# IPG record saved to 'ipg_report/ipg_202407621.txt'
# IPG record saved to 'ipg_report/ipg_202381165.txt'
# IPG record saved to 'ipg_report/ipg_202273109.txt'
# IPG record saved to 'ipg_report/ipg_202273105.txt'
# IPG record saved to 'ipg_report/ipg_197901825.txt'
# IPG record saved to 'ipg_report/ipg_187786903.txt'
# IPG record saved to 'ipg_report/ipg_187786899.txt'
# IPG record saved to 'ipg_report/ipg_162735280.txt'
# IPG record saved to 'ipg_report/ipg_148693676.txt'
# IPG record saved to 'ipg_report/ipg_135232592.txt'
# IPG record saved to 'ipg_report/ipg_130803200.txt'
# IPG record saved to 'ipg_report/ipg_120326486.txt'
# IPG record saved to 'ipg_report/ipg_119562576.txt'
# IPG record saved to 'ipg_report/ipg_115917827.txt'
# IPG record saved to 'ipg_report/ipg_110735072.txt'
# IPG record saved to 'ipg_report/ipg_104891990.txt'
# IPG record saved to 'ipg_report/ipg_100273892.txt'
# IPG record saved to 'ipg_report/ipg_93192446.txt'
# IPG record saved to 'ipg_report/ipg_93026178.txt'
# IPG record saved to 'ipg_report/ipg_92998555.txt'
# IPG record saved to 'ipg_report/ipg_92988082.txt'
# IPG record saved to 'ipg_report/ipg_92956506.txt'
# IPG record saved to 'ipg_report/ipg_87874508.txt'
# IPG record saved to 'ipg_report/ipg_80448363.txt'
# IPG record saved to 'ipg_report/ipg_73898866.txt'
# IPG record saved to 'ipg_report/ipg_73126069.txt'
# IPG record saved to 'ipg_report/ipg_67613453.txt'
# IPG record saved to 'ipg_report/ipg_67612290.txt'
# IPG record saved to 'ipg_report/ipg_63695598.txt'
# IPG record saved to 'ipg_report/ipg_60522591.txt'
# IPG record saved to 'ipg_report/ipg_44852562.txt'
# IPG record saved to 'ipg_report/ipg_43801700.txt'
# IPG record saved to 'ipg_report/ipg_41999083.txt'
# IPG record saved to 'ipg_report/ipg_41989300.txt'
# IPG record saved to 'ipg_report/ipg_41890630.txt'
# IPG record saved to 'ipg_report/ipg_41642843.txt'
# IPG record saved to 'ipg_report/ipg_24712516.txt'
# IPG record saved to 'ipg_report/ipg_24188088.txt'
# IPG record saved to 'ipg_report/ipg_24188079.txt'
# IPG record saved to 'ipg_report/ipg_20538028.txt'
# IPG record saved to 'ipg_report/ipg_18545529.txt'
# IPG record saved to 'ipg_report/ipg_16703718.txt'
# IPG record saved to 'ipg_report/ipg_16656375.txt'
# IPG record saved to 'ipg_report/ipg_14222882.txt'
# IPG record saved to 'ipg_report/ipg_13112137.txt'
# IPG record saved to 'ipg_report/ipg_5003682.txt'
# IPG record saved to 'ipg_report/ipg_4013657.txt'
# IPG record saved to 'ipg_report/ipg_644865337.txt'
# IPG record saved to 'ipg_report/ipg_644832722.txt'
# IPG record saved to 'ipg_report/ipg_644832720.txt'
# IPG record saved to 'ipg_report/ipg_644372625.txt'
# IPG record saved to 'ipg_report/ipg_644372610.txt'
# IPG record saved to 'ipg_report/ipg_204271266.txt'
# IPG record saved to 'ipg_report/ipg_204271244.txt'
# IPG record saved to 'ipg_report/ipg_204255637.txt'
# IPG record saved to 'ipg_report/ipg_204070932.txt'
# IPG record saved to 'ipg_report/ipg_204070908.txt'
# IPG record saved to 'ipg_report/ipg_204066250.txt'
# IPG record saved to 'ipg_report/ipg_204066232.txt'
# IPG record saved to 'ipg_report/ipg_204004500.txt'
# IPG record saved to 'ipg_report/ipg_203989088.txt'
# IPG record saved to 'ipg_report/ipg_202473258.txt'
# IPG record saved to 'ipg_report/ipg_202377934.txt'
# IPG record saved to 'ipg_report/ipg_202376275.txt'
# IPG record saved to 'ipg_report/ipg_202319452.txt'
# IPG record saved to 'ipg_report/ipg_202279492.txt'
# IPG record saved to 'ipg_report/ipg_202260325.txt'
# IPG record saved to 'ipg_report/ipg_202252791.txt'
# IPG record saved to 'ipg_report/ipg_202228202.txt'
# IPG record saved to 'ipg_report/ipg_202193836.txt'
# IPG record saved to 'ipg_report/ipg_202038747.txt'
# IPG record saved to 'ipg_report/ipg_202038728.txt'
# IPG record saved to 'ipg_report/ipg_197801753.txt'
# IPG record saved to 'ipg_report/ipg_197795753.txt'
# IPG record saved to 'ipg_report/ipg_196958911.txt'
# IPG record saved to 'ipg_report/ipg_196958886.txt'
# IPG record saved to 'ipg_report/ipg_190463528.txt'
# IPG record saved to 'ipg_report/ipg_190462146.txt'
# IPG record saved to 'ipg_report/ipg_189324247.txt'
# IPG record saved to 'ipg_report/ipg_189190541.txt'
# IPG record saved to 'ipg_report/ipg_188167619.txt'
# IPG record saved to 'ipg_report/ipg_188166276.txt'
# IPG record saved to 'ipg_report/ipg_188163405.txt'
# IPG record saved to 'ipg_report/ipg_183529552.txt'
# IPG record saved to 'ipg_report/ipg_180130208.txt'
# IPG record saved to 'ipg_report/ipg_180129727.txt'
# IPG record saved to 'ipg_report/ipg_180126948.txt'
# IPG record saved to 'ipg_report/ipg_176071484.txt'
# IPG record saved to 'ipg_report/ipg_168485316.txt'
# IPG record saved to 'ipg_report/ipg_168480689.txt'
# IPG record saved to 'ipg_report/ipg_168419787.txt'
# IPG record saved to 'ipg_report/ipg_162720486.txt'
# IPG record saved to 'ipg_report/ipg_159425990.txt'
# IPG record saved to 'ipg_report/ipg_157844027.txt'
# IPG record saved to 'ipg_report/ipg_156942378.txt'
# IPG record saved to 'ipg_report/ipg_154231392.txt'
# IPG record saved to 'ipg_report/ipg_147833794.txt'
# IPG record saved to 'ipg_report/ipg_143821733.txt'
# IPG record saved to 'ipg_report/ipg_139882775.txt'
# IPG record saved to 'ipg_report/ipg_139250543.txt'
# IPG record saved to 'ipg_report/ipg_139250204.txt'
# IPG record saved to 'ipg_report/ipg_139248114.txt'
# IPG record saved to 'ipg_report/ipg_138898023.txt'
# IPG record saved to 'ipg_report/ipg_134172220.txt'
# IPG record saved to 'ipg_report/ipg_133180339.txt'
# IPG record saved to 'ipg_report/ipg_132095142.txt'
# IPG record saved to 'ipg_report/ipg_131991320.txt'
# IPG record saved to 'ipg_report/ipg_131990941.txt'
# IPG record saved to 'ipg_report/ipg_131989249.txt'
# IPG record saved to 'ipg_report/ipg_130953677.txt'
# IPG record saved to 'ipg_report/ipg_130953282.txt'
# IPG record saved to 'ipg_report/ipg_130953189.txt'
# IPG record saved to 'ipg_report/ipg_130952038.txt'
# IPG record saved to 'ipg_report/ipg_130950391.txt'
# IPG record saved to 'ipg_report/ipg_130849297.txt'
# IPG record saved to 'ipg_report/ipg_130800655.txt'
# IPG record saved to 'ipg_report/ipg_130734924.txt'
# IPG record saved to 'ipg_report/ipg_130733584.txt'
# IPG record saved to 'ipg_report/ipg_130728297.txt'
# IPG record saved to 'ipg_report/ipg_130659761.txt'
# IPG record saved to 'ipg_report/ipg_130659031.txt'
# IPG record saved to 'ipg_report/ipg_130658562.txt'
# IPG record saved to 'ipg_report/ipg_130658423.txt'
# IPG record saved to 'ipg_report/ipg_130657505.txt'
# IPG record saved to 'ipg_report/ipg_130496698.txt'
# IPG record saved to 'ipg_report/ipg_130392522.txt'
# IPG record saved to 'ipg_report/ipg_130375660.txt'
# IPG record saved to 'ipg_report/ipg_127583629.txt'
# IPG record saved to 'ipg_report/ipg_127583626.txt'
# IPG record saved to 'ipg_report/ipg_127378582.txt'
# IPG record saved to 'ipg_report/ipg_127098907.txt'
# IPG record saved to 'ipg_report/ipg_127096811.txt'
# IPG record saved to 'ipg_report/ipg_127096810.txt'
# IPG record saved to 'ipg_report/ipg_126899012.txt'
# IPG record saved to 'ipg_report/ipg_126471353.txt'
# IPG record saved to 'ipg_report/ipg_126469379.txt'
# IPG record saved to 'ipg_report/ipg_126365473.txt'
# IPG record saved to 'ipg_report/ipg_126318187.txt'
# IPG record saved to 'ipg_report/ipg_126316590.txt'
# IPG record saved to 'ipg_report/ipg_126298629.txt'
# IPG record saved to 'ipg_report/ipg_126172259.txt'
# IPG record saved to 'ipg_report/ipg_126172256.txt'
# IPG record saved to 'ipg_report/ipg_126091454.txt'
# IPG record saved to 'ipg_report/ipg_126049439.txt'
# IPG record saved to 'ipg_report/ipg_125977426.txt'
# IPG record saved to 'ipg_report/ipg_124664001.txt'
# IPG record saved to 'ipg_report/ipg_124598403.txt'
# IPG record saved to 'ipg_report/ipg_124576364.txt'
# IPG record saved to 'ipg_report/ipg_123257938.txt'
# IPG record saved to 'ipg_report/ipg_123257926.txt'
# IPG record saved to 'ipg_report/ipg_123255769.txt'
# IPG record saved to 'ipg_report/ipg_123255766.txt'
# IPG record saved to 'ipg_report/ipg_123252967.txt'
# IPG record saved to 'ipg_report/ipg_123105094.txt'
# IPG record saved to 'ipg_report/ipg_123062981.txt'
# IPG record saved to 'ipg_report/ipg_122948252.txt'
# IPG record saved to 'ipg_report/ipg_122888853.txt'
# IPG record saved to 'ipg_report/ipg_122878649.txt'
# IPG record saved to 'ipg_report/ipg_122878564.txt'
# IPG record saved to 'ipg_report/ipg_120764462.txt'
# IPG record saved to 'ipg_report/ipg_120627158.txt'
# IPG record saved to 'ipg_report/ipg_119618691.txt'
# IPG record saved to 'ipg_report/ipg_115470104.txt'
# IPG record saved to 'ipg_report/ipg_115467886.txt'
# IPG record saved to 'ipg_report/ipg_109187166.txt'
# IPG record saved to 'ipg_report/ipg_109184098.txt'
# IPG record saved to 'ipg_report/ipg_109184091.txt'
# IPG record saved to 'ipg_report/ipg_108046248.txt'
# IPG record saved to 'ipg_report/ipg_108045975.txt'
# IPG record saved to 'ipg_report/ipg_104614542.txt'
# IPG record saved to 'ipg_report/ipg_94620911.txt'
# IPG record saved to 'ipg_report/ipg_93834847.txt'
# IPG record saved to 'ipg_report/ipg_93834102.txt'
# IPG record saved to 'ipg_report/ipg_93033328.txt'
# IPG record saved to 'ipg_report/ipg_93033324.txt'
# IPG record saved to 'ipg_report/ipg_93024575.txt'
# IPG record saved to 'ipg_report/ipg_93024571.txt'
# IPG record saved to 'ipg_report/ipg_93017433.txt'
# IPG record saved to 'ipg_report/ipg_93014389.txt'
# IPG record saved to 'ipg_report/ipg_92979612.txt'
# IPG record saved to 'ipg_report/ipg_92971004.txt'
# IPG record saved to 'ipg_report/ipg_92141264.txt'
# IPG record saved to 'ipg_report/ipg_92139781.txt'
# IPG record saved to 'ipg_report/ipg_90999094.txt'
# IPG record saved to 'ipg_report/ipg_90506582.txt'
# IPG record saved to 'ipg_report/ipg_88036440.txt'
# IPG record saved to 'ipg_report/ipg_87655583.txt'
# IPG record saved to 'ipg_report/ipg_84668267.txt'
# IPG record saved to 'ipg_report/ipg_80474365.txt'
# IPG record saved to 'ipg_report/ipg_80454678.txt'
# IPG record saved to 'ipg_report/ipg_79608603.txt'
# IPG record saved to 'ipg_report/ipg_78875458.txt'
# IPG record saved to 'ipg_report/ipg_69551635.txt'
# IPG record saved to 'ipg_report/ipg_63619915.txt'
# IPG record saved to 'ipg_report/ipg_63619908.txt'
# IPG record saved to 'ipg_report/ipg_61022931.txt'
# IPG record saved to 'ipg_report/ipg_60425492.txt'
# IPG record saved to 'ipg_report/ipg_57233996.txt'
# IPG record saved to 'ipg_report/ipg_57233990.txt'
# IPG record saved to 'ipg_report/ipg_56249907.txt'
# IPG record saved to 'ipg_report/ipg_55378950.txt'
# IPG record saved to 'ipg_report/ipg_54585016.txt'
# IPG record saved to 'ipg_report/ipg_52449708.txt'
# IPG record saved to 'ipg_report/ipg_50918799.txt'
# IPG record saved to 'ipg_report/ipg_47103436.txt'
# IPG record saved to 'ipg_report/ipg_44445171.txt'
# IPG record saved to 'ipg_report/ipg_44430214.txt'
# IPG record saved to 'ipg_report/ipg_44427410.txt'
# IPG record saved to 'ipg_report/ipg_43788286.txt'
# IPG record saved to 'ipg_report/ipg_24712524.txt'
# IPG record saved to 'ipg_report/ipg_22259336.txt'
# IPG record saved to 'ipg_report/ipg_20538021.txt'
# IPG record saved to 'ipg_report/ipg_19757945.txt'
# IPG record saved to 'ipg_report/ipg_19670825.txt'
# IPG record saved to 'ipg_report/ipg_18266017.txt'
# IPG record saved to 'ipg_report/ipg_18266010.txt'
# IPG record saved to 'ipg_report/ipg_14531677.txt'
# IPG record saved to 'ipg_report/ipg_14178485.txt'
# IPG record saved to 'ipg_report/ipg_644352252.txt'
# IPG record saved to 'ipg_report/ipg_141175262.txt'
# IPG record saved to 'ipg_report/ipg_141174477.txt'
# IPG record saved to 'ipg_report/ipg_130646424.txt'
# IPG record saved to 'ipg_report/ipg_73250572.txt'
# IPG record saved to 'ipg_report/ipg_64730185.txt'
# IPG record saved to 'ipg_report/ipg_60427177.txt'
# IPG record saved to 'ipg_report/ipg_58160562.txt'
# IPG record saved to 'ipg_report/ipg_57973559.txt'
# IPG record saved to 'ipg_report/ipg_56516802.txt'
# IPG record saved to 'ipg_report/ipg_56512046.txt'
# IPG record saved to 'ipg_report/ipg_56512043.txt'
# IPG record saved to 'ipg_report/ipg_56507451.txt'
# IPG record saved to 'ipg_report/ipg_56507448.txt'
# IPG record saved to 'ipg_report/ipg_56094226.txt'
# IPG record saved to 'ipg_report/ipg_55876335.txt'
# IPG record saved to 'ipg_report/ipg_55666903.txt'
# IPG record saved to 'ipg_report/ipg_55587578.txt'
# IPG record saved to 'ipg_report/ipg_55584659.txt'
# IPG record saved to 'ipg_report/ipg_55581582.txt'
# IPG record saved to 'ipg_report/ipg_54839013.txt'
# IPG record saved to 'ipg_report/ipg_54385491.txt'
# IPG record saved to 'ipg_report/ipg_54298296.txt'
# IPG record saved to 'ipg_report/ipg_51821190.txt'
# IPG record saved to 'ipg_report/ipg_51818049.txt'
# IPG record saved to 'ipg_report/ipg_51670872.txt'
# IPG record saved to 'ipg_report/ipg_51668556.txt'
# IPG record saved to 'ipg_report/ipg_51668237.txt'
# IPG record saved to 'ipg_report/ipg_38361636.txt'
# IPG record saved to 'ipg_report/ipg_35794188.txt'
# IPG record saved to 'ipg_report/ipg_33769911.txt'
# IPG record saved to 'ipg_report/ipg_33769899.txt'
# ...
# IPG record saved to 'ipg_report/ipg_6478874.txt'
# IPG record saved to 'ipg_report/ipg_6468499.txt'
# IPG record saved to 'ipg_report/ipg_6379110.txt'
# IPG record saved to 'ipg_report/ipg_6303804.txt'
# IPG record saved to 'ipg_report/ipg_6303801.txt'
# IPG record saved to 'ipg_report/ipg_6303797.txt'
# IPG record saved to 'ipg_report/ipg_6143874.txt'
# IPG record saved to 'ipg_report/ipg_6142329.txt'
# IPG record saved to 'ipg_report/ipg_6140833.txt'
# IPG record saved to 'ipg_report/ipg_6138266.txt'
# IPG record saved to 'ipg_report/ipg_6137943.txt'
# IPG record saved to 'ipg_report/ipg_5856105.txt'
# IPG record saved to 'ipg_report/ipg_5856104.txt'
# IPG record saved to 'ipg_report/ipg_5847335.txt'
# IPG record saved to 'ipg_report/ipg_5847274.txt'
# IPG record saved to 'ipg_report/ipg_5826642.txt'
# IPG record saved to 'ipg_report/ipg_5734170.txt'
# IPG record saved to 'ipg_report/ipg_1436580.txt'
# IPG record saved to 'ipg_report/ipg_1426863.txt'
# IPG record saved to 'ipg_report/ipg_1348347.txt'
# IPG record saved to 'ipg_report/ipg_1250174.txt'
# IPG record saved to 'ipg_report/ipg_1226732.txt'
# IPG record saved to 'ipg_report/ipg_1055817.txt'
# IPG record saved to 'ipg_report/ipg_1014295.txt'
# IPG record saved to 'ipg_report/ipg_875787.txt'
# IPG record saved to 'ipg_report/ipg_874410.txt'
# IPG record saved to 'ipg_report/ipg_669854.txt'
# IPG record saved to 'ipg_report/ipg_632057.txt'
# IPG record saved to 'ipg_report/ipg_603066.txt'
# IPG record saved to 'ipg_report/ipg_440665.txt'
# IPG record saved to 'ipg_report/ipg_298427.txt'
# IPG record saved to 'ipg_report/ipg_243563.txt'
# IPG record saved to 'ipg_report/ipg_182449.txt'
# IPG record saved to 'ipg_report/ipg_181659.txt'
# IPG record saved to 'ipg_report/ipg_115527.txt'
# IPG record saved to 'ipg_report/ipg_99643.txt'
# IPG record saved to 'ipg_report/ipg_113117422.txt'
# IPG record saved to 'ipg_report/ipg_75406467.txt'
# IPG record saved to 'ipg_report/ipg_43638035.txt'
# IPG record saved to 'ipg_report/ipg_43638034.txt'
# IPG record saved to 'ipg_report/ipg_43638033.txt'
# IPG record saved to 'ipg_report/ipg_43638032.txt'
# IPG record saved to 'ipg_report/ipg_43638031.txt'
# IPG record saved to 'ipg_report/ipg_43638030.txt'
# IPG record saved to 'ipg_report/ipg_43638029.txt'
# IPG record saved to 'ipg_report/ipg_43638028.txt'
# IPG record saved to 'ipg_report/ipg_43638027.txt'
# IPG record saved to 'ipg_report/ipg_109131702.txt'
# IPG record saved to 'ipg_report/ipg_109128571.txt'
# IPG record saved to 'ipg_report/ipg_106045775.txt'
# IPG record saved to 'ipg_report/ipg_106042988.txt'
# IPG record saved to 'ipg_report/ipg_104947414.txt'
# IPG record saved to 'ipg_report/ipg_104945850.txt'
# IPG record saved to 'ipg_report/ipg_66395022.txt'
# IPG record saved to 'ipg_report/ipg_66395021.txt'
# IPG record saved to 'ipg_report/ipg_66395020.txt'
# IPG record saved to 'ipg_report/ipg_66395019.txt'
# IPG record saved to 'ipg_report/ipg_66395017.txt'
# IPG record saved to 'ipg_report/ipg_66395016.txt'
# IPG record saved to 'ipg_report/ipg_66395015.txt'
# IPG record saved to 'ipg_report/ipg_66395014.txt'
# IPG record saved to 'ipg_report/ipg_66395013.txt'
# IPG record saved to 'ipg_report/ipg_101028770.txt'
# IPG record saved to 'ipg_report/ipg_100920789.txt'
# IPG record saved to 'ipg_report/ipg_100435377.txt'
# IPG record saved to 'ipg_report/ipg_100427554.txt'
# IPG record saved to 'ipg_report/ipg_100427285.txt'
# IPG record saved to 'ipg_report/ipg_100425817.txt'
# IPG record saved to 'ipg_report/ipg_100424661.txt'
# IPG record saved to 'ipg_report/ipg_49880639.txt'
# IPG record saved to 'ipg_report/ipg_35398103.txt'
# IPG record saved to 'ipg_report/ipg_87296243.txt'
# IPG record saved to 'ipg_report/ipg_87296242.txt'
# IPG record saved to 'ipg_report/ipg_87296241.txt'
# IPG record saved to 'ipg_report/ipg_87296240.txt'
# IPG record saved to 'ipg_report/ipg_87296239.txt'
# IPG record saved to 'ipg_report/ipg_87296238.txt'
# IPG record saved to 'ipg_report/ipg_87296237.txt'
# IPG record saved to 'ipg_report/ipg_87296236.txt'
# IPG record saved to 'ipg_report/ipg_87296235.txt'
# IPG record saved to 'ipg_report/ipg_87296234.txt'
# IPG record saved to 'ipg_report/ipg_87296233.txt'
# IPG record saved to 'ipg_report/ipg_87296232.txt'
# IPG record saved to 'ipg_report/ipg_87296231.txt'
# IPG record saved to 'ipg_report/ipg_87296230.txt'
# IPG record saved to 'ipg_report/ipg_87296229.txt'
# IPG record saved to 'ipg_report/ipg_87296228.txt'
# IPG record saved to 'ipg_report/ipg_87296227.txt'
# IPG record saved to 'ipg_report/ipg_87296226.txt'
# IPG record saved to 'ipg_report/ipg_87296225.txt'
# IPG record saved to 'ipg_report/ipg_87296224.txt'
# IPG record saved to 'ipg_report/ipg_87296223.txt'
# IPG record saved to 'ipg_report/ipg_87296222.txt'
# IPG record saved to 'ipg_report/ipg_87296221.txt'
# IPG record saved to 'ipg_report/ipg_87296220.txt'
# IPG record saved to 'ipg_report/ipg_87296219.txt'
# IPG record saved to 'ipg_report/ipg_97096936.txt'
# IPG record saved to 'ipg_report/ipg_97096935.txt'
# IPG record saved to 'ipg_report/ipg_97096934.txt'
# IPG record saved to 'ipg_report/ipg_97096933.txt'
# IPG record saved to 'ipg_report/ipg_45785413.txt'
# IPG record saved to 'ipg_report/ipg_95564533.txt'
# IPG record saved to 'ipg_report/ipg_50458901.txt'
# IPG record saved to 'ipg_report/ipg_50456861.txt'
# IPG record saved to 'ipg_report/ipg_93930063.txt'
# IPG record saved to 'ipg_report/ipg_93930062.txt'
# IPG record saved to 'ipg_report/ipg_93930061.txt'
# IPG record saved to 'ipg_report/ipg_93930060.txt'
# IPG record saved to 'ipg_report/ipg_93630781.txt'
# IPG record saved to 'ipg_report/ipg_93303054.txt'
# IPG record saved to 'ipg_report/ipg_6889346.txt'
# IPG record saved to 'ipg_report/ipg_92765882.txt'
# IPG record saved to 'ipg_report/ipg_92732543.txt'
# IPG record saved to 'ipg_report/ipg_92040390.txt'
# IPG record saved to 'ipg_report/ipg_92040389.txt'
# IPG record saved to 'ipg_report/ipg_92040388.txt'
# IPG record saved to 'ipg_report/ipg_92040387.txt'
# IPG record saved to 'ipg_report/ipg_92040386.txt'
# IPG record saved to 'ipg_report/ipg_92040384.txt'
# IPG record saved to 'ipg_report/ipg_92040383.txt'
# IPG record saved to 'ipg_report/ipg_92040382.txt'
# IPG record saved to 'ipg_report/ipg_92040381.txt'
# IPG record saved to 'ipg_report/ipg_92040380.txt'
# IPG record saved to 'ipg_report/ipg_92040379.txt'
# IPG record saved to 'ipg_report/ipg_91647769.txt'
# IPG record saved to 'ipg_report/ipg_91647768.txt'
# IPG record saved to 'ipg_report/ipg_91647767.txt'
# IPG record saved to 'ipg_report/ipg_91206824.txt'
# IPG record saved to 'ipg_report/ipg_90788059.txt'
# IPG record saved to 'ipg_report/ipg_89998150.txt'
# IPG record saved to 'ipg_report/ipg_89998149.txt'
# IPG record saved to 'ipg_report/ipg_89998148.txt'
# IPG record saved to 'ipg_report/ipg_89998147.txt'
# IPG record saved to 'ipg_report/ipg_89998146.txt'
# IPG record saved to 'ipg_report/ipg_89998145.txt'
# IPG record saved to 'ipg_report/ipg_89998144.txt'
# IPG record saved to 'ipg_report/ipg_89998143.txt'
# IPG record saved to 'ipg_report/ipg_89998142.txt'
# IPG record saved to 'ipg_report/ipg_89998141.txt'
# IPG record saved to 'ipg_report/ipg_89564252.txt'
# IPG record saved to 'ipg_report/ipg_89564251.txt'
# IPG record saved to 'ipg_report/ipg_87997200.txt'
# IPG record saved to 'ipg_report/ipg_87997199.txt'
# IPG record saved to 'ipg_report/ipg_87997198.txt'
# IPG record saved to 'ipg_report/ipg_87997197.txt'
# IPG record saved to 'ipg_report/ipg_87997196.txt'
# IPG record saved to 'ipg_report/ipg_87997195.txt'
# IPG record saved to 'ipg_report/ipg_87997194.txt'
# IPG record saved to 'ipg_report/ipg_87997193.txt'
# IPG record saved to 'ipg_report/ipg_87997192.txt'
# IPG record saved to 'ipg_report/ipg_87997190.txt'
# IPG record saved to 'ipg_report/ipg_87997189.txt'
# IPG record saved to 'ipg_report/ipg_87997188.txt'
# IPG record saved to 'ipg_report/ipg_87997187.txt'
# IPG record saved to 'ipg_report/ipg_87997186.txt'
# IPG record saved to 'ipg_report/ipg_87997185.txt'
# IPG record saved to 'ipg_report/ipg_87997184.txt'
# IPG record saved to 'ipg_report/ipg_87997183.txt'
# IPG record saved to 'ipg_report/ipg_61476417.txt'
# IPG record saved to 'ipg_report/ipg_77720622.txt'
# IPG record saved to 'ipg_report/ipg_41699674.txt'
# IPG record saved to 'ipg_report/ipg_35398102.txt'
# IPG record saved to 'ipg_report/ipg_49481383.txt'
# IPG record saved to 'ipg_report/ipg_80122460.txt'
# IPG record saved to 'ipg_report/ipg_1529610.txt'
# IPG record saved to 'ipg_report/ipg_23116186.txt'
# IPG record saved to 'ipg_report/ipg_3966453.txt'
# IPG record saved to 'ipg_report/ipg_78730035.txt'
# IPG record saved to 'ipg_report/ipg_42821995.txt'
# IPG record saved to 'ipg_report/ipg_19701577.txt'
# IPG record saved to 'ipg_report/ipg_19677882.txt'
# IPG record saved to 'ipg_report/ipg_49880640.txt'
# IPG record saved to 'ipg_report/ipg_73698179.txt'
# IPG record saved to 'ipg_report/ipg_62767695.txt'
# IPG record saved to 'ipg_report/ipg_62822526.txt'
# IPG record saved to 'ipg_report/ipg_62809519.txt'
# IPG record saved to 'ipg_report/ipg_31260204.txt'
# IPG record saved to 'ipg_report/ipg_31260203.txt'
# IPG record saved to 'ipg_report/ipg_31260202.txt'
# IPG record saved to 'ipg_report/ipg_5376173.txt'
# IPG record saved to 'ipg_report/ipg_60930606.txt'
# IPG record saved to 'ipg_report/ipg_57627906.txt'
# IPG record saved to 'ipg_report/ipg_51495443.txt'
# IPG record saved to 'ipg_report/ipg_51495442.txt'
# IPG record saved to 'ipg_report/ipg_51495441.txt'
# IPG record saved to 'ipg_report/ipg_51495440.txt'
# IPG record saved to 'ipg_report/ipg_51495439.txt'
# IPG record saved to 'ipg_report/ipg_51495438.txt'
# IPG record saved to 'ipg_report/ipg_51495437.txt'
# IPG record saved to 'ipg_report/ipg_51495436.txt'
# IPG record saved to 'ipg_report/ipg_51495435.txt'
# IPG record saved to 'ipg_report/ipg_51495434.txt'
# IPG record saved to 'ipg_report/ipg_51495433.txt'
# IPG record saved to 'ipg_report/ipg_51495432.txt'
# IPG record saved to 'ipg_report/ipg_51495431.txt'
# IPG record saved to 'ipg_report/ipg_47666430.txt'
# IPG record saved to 'ipg_report/ipg_50768589.txt'
# IPG record saved to 'ipg_report/ipg_50768588.txt'
# IPG record saved to 'ipg_report/ipg_48397197.txt'
# IPG record saved to 'ipg_report/ipg_49030589.txt'
# IPG record saved to 'ipg_report/ipg_31556632.txt'
# IPG record saved to 'ipg_report/ipg_34649647.txt'
# IPG record saved to 'ipg_report/ipg_1288069.txt'
# IPG record saved to 'ipg_report/ipg_47067839.txt'
# IPG record saved to 'ipg_report/ipg_46636197.txt'
# IPG record saved to 'ipg_report/ipg_46636195.txt'
# IPG record saved to 'ipg_report/ipg_46636194.txt'
# IPG record saved to 'ipg_report/ipg_46636193.txt'
# IPG record saved to 'ipg_report/ipg_46636192.txt'
# IPG record saved to 'ipg_report/ipg_46636190.txt'
# IPG record saved to 'ipg_report/ipg_46636189.txt'
# IPG record saved to 'ipg_report/ipg_46636188.txt'
# IPG record saved to 'ipg_report/ipg_46636186.txt'
# IPG record saved to 'ipg_report/ipg_46636185.txt'
# IPG record saved to 'ipg_report/ipg_46636183.txt'
# IPG record saved to 'ipg_report/ipg_46636182.txt'
# IPG record saved to 'ipg_report/ipg_46636181.txt'
# IPG record saved to 'ipg_report/ipg_46636180.txt'
# IPG record saved to 'ipg_report/ipg_46636179.txt'
# IPG record saved to 'ipg_report/ipg_46636178.txt'
# IPG record saved to 'ipg_report/ipg_46636177.txt'
# IPG record saved to 'ipg_report/ipg_46216662.txt'
# IPG record saved to 'ipg_report/ipg_46203571.txt'
# IPG record saved to 'ipg_report/ipg_31362564.txt'
# IPG record saved to 'ipg_report/ipg_31247958.txt'
# IPG record saved to 'ipg_report/ipg_31246117.txt'
# IPG record saved to 'ipg_report/ipg_31245761.txt'
# IPG record saved to 'ipg_report/ipg_14072226.txt'
# IPG record saved to 'ipg_report/ipg_14072225.txt'
# IPG record saved to 'ipg_report/ipg_22017399.txt'
# IPG record saved to 'ipg_report/ipg_42870288.txt'
# IPG record saved to 'ipg_report/ipg_42835023.txt'
# IPG record saved to 'ipg_report/ipg_42832332.txt'
# IPG record saved to 'ipg_report/ipg_31728291.txt'
# IPG record saved to 'ipg_report/ipg_34520661.txt'
# IPG record saved to 'ipg_report/ipg_42125805.txt'
# IPG record saved to 'ipg_report/ipg_42108726.txt'
# IPG record saved to 'ipg_report/ipg_34688228.txt'
# IPG record saved to 'ipg_report/ipg_27040954.txt'
# IPG record saved to 'ipg_report/ipg_18893351.txt'
# IPG record saved to 'ipg_report/ipg_18893350.txt'
# IPG record saved to 'ipg_report/ipg_18893349.txt'
# IPG record saved to 'ipg_report/ipg_18893348.txt'
# IPG record saved to 'ipg_report/ipg_18893347.txt'
# IPG record saved to 'ipg_report/ipg_18893346.txt'
# IPG record saved to 'ipg_report/ipg_26334247.txt'
# IPG record saved to 'ipg_report/ipg_754728.txt'
# IPG record saved to 'ipg_report/ipg_20835004.txt'
# IPG record saved to 'ipg_report/ipg_31249597.txt'
# IPG record saved to 'ipg_report/ipg_20572387.txt'
# IPG record saved to 'ipg_report/ipg_13922590.txt'
# IPG record saved to 'ipg_report/ipg_29936261.txt'
# IPG record saved to 'ipg_report/ipg_23877660.txt'
# IPG record saved to 'ipg_report/ipg_27230611.txt'
# IPG record saved to 'ipg_report/ipg_27230610.txt'
# IPG record saved to 'ipg_report/ipg_27230609.txt'
# IPG record saved to 'ipg_report/ipg_27230608.txt'
# IPG record saved to 'ipg_report/ipg_27230607.txt'
# IPG record saved to 'ipg_report/ipg_27230606.txt'
# IPG record saved to 'ipg_report/ipg_27230605.txt'
# IPG record saved to 'ipg_report/ipg_27230604.txt'
# IPG record saved to 'ipg_report/ipg_27149889.txt'
# IPG record saved to 'ipg_report/ipg_21965684.txt'
# IPG record saved to 'ipg_report/ipg_19812787.txt'
# IPG record saved to 'ipg_report/ipg_19812786.txt'
# IPG record saved to 'ipg_report/ipg_19812785.txt'
# IPG record saved to 'ipg_report/ipg_18745590.txt'
# IPG record saved to 'ipg_report/ipg_27293016.txt'
# IPG record saved to 'ipg_report/ipg_23635892.txt'
# IPG record saved to 'ipg_report/ipg_23635891.txt'
# IPG record saved to 'ipg_report/ipg_23635890.txt'
# IPG record saved to 'ipg_report/ipg_23635889.txt'
# IPG record saved to 'ipg_report/ipg_23635888.txt'
# IPG record saved to 'ipg_report/ipg_23635887.txt'
# IPG record saved to 'ipg_report/ipg_26870962.txt'
# IPG record saved to 'ipg_report/ipg_20004356.txt'
# IPG record saved to 'ipg_report/ipg_20771225.txt'
# IPG record saved to 'ipg_report/ipg_20771224.txt'
# IPG record saved to 'ipg_report/ipg_20771223.txt'
# IPG record saved to 'ipg_report/ipg_20771222.txt'
# IPG record saved to 'ipg_report/ipg_20771221.txt'
# IPG record saved to 'ipg_report/ipg_20771220.txt'
# IPG record saved to 'ipg_report/ipg_20771219.txt'
# IPG record saved to 'ipg_report/ipg_20771218.txt'
# IPG record saved to 'ipg_report/ipg_20771217.txt'
# IPG record saved to 'ipg_report/ipg_20771216.txt'
# IPG record saved to 'ipg_report/ipg_20771215.txt'
# IPG record saved to 'ipg_report/ipg_24162822.txt'
# IPG record saved to 'ipg_report/ipg_20804220.txt'
# IPG record saved to 'ipg_report/ipg_16772631.txt'
# IPG record saved to 'ipg_report/ipg_17614232.txt'
# IPG record saved to 'ipg_report/ipg_17614231.txt'
# IPG record saved to 'ipg_report/ipg_17614230.txt'
# IPG record saved to 'ipg_report/ipg_17614229.txt'
# IPG record saved to 'ipg_report/ipg_17614228.txt'
# IPG record saved to 'ipg_report/ipg_17614227.txt'
# IPG record saved to 'ipg_report/ipg_17614226.txt'
# IPG record saved to 'ipg_report/ipg_17614225.txt'
# IPG record saved to 'ipg_report/ipg_17614224.txt'
# IPG record saved to 'ipg_report/ipg_17614223.txt'
# IPG record saved to 'ipg_report/ipg_17614222.txt'
# IPG record saved to 'ipg_report/ipg_17614221.txt'
# IPG record saved to 'ipg_report/ipg_17614220.txt'
# IPG record saved to 'ipg_report/ipg_5376189.txt'
# IPG record saved to 'ipg_report/ipg_5375208.txt'
# IPG record saved to 'ipg_report/ipg_5375133.txt'
# IPG record saved to 'ipg_report/ipg_5374524.txt'
# IPG record saved to 'ipg_report/ipg_16450037.txt'
# IPG record saved to 'ipg_report/ipg_16450036.txt'
# IPG record saved to 'ipg_report/ipg_4192924.txt'
# IPG record saved to 'ipg_report/ipg_4192920.txt'
# IPG record saved to 'ipg_report/ipg_5376266.txt'
# IPG record saved to 'ipg_report/ipg_5376128.txt'
# IPG record saved to 'ipg_report/ipg_5376115.txt'
# IPG record saved to 'ipg_report/ipg_5376109.txt'
# IPG record saved to 'ipg_report/ipg_5375979.txt'
# IPG record saved to 'ipg_report/ipg_5003626.txt'
# IPG record saved to 'ipg_report/ipg_3607909.txt'
# IPG record saved to 'ipg_report/ipg_511568.txt'
# IPG record saved to 'ipg_report/ipg_168900.txt'
# IPG record saved to 'ipg_report/ipg_496821.txt'

# %% [markdown]
# ## 3. Extract the first line of the IPG report present in NCBI and put it in a table (23 sec)
#
# - extract first line
# - make a table with the accession number, star, stop and the strand of the sequence

# %%
import pandas as pd
import numpy as np


gene_list = pd.DataFrame(columns=["accession", "start", "stop", "strand"])

for name in seq_id:
    file = "ipg_report/ipg_"+name+".txt"
    ipg = pd.read_csv(file, sep="\t")

    insdc = np.array(ipg.loc[:, "Source"] == "INSDC", dtype="bool")
    refseq = np.array(ipg.loc[:, "Source"] == "RefSeq", dtype="bool")

    in_ncbi = ipg.loc[refseq | insdc, :]
    in_ncbi = in_ncbi.reset_index()
    url = str()
    if len(in_ncbi) != 0:
        name = str(in_ncbi.loc[0, "Nucleotide Accession"])
        start = str(in_ncbi.loc[0, "Start"])
        stop = str(in_ncbi.loc[0, "Stop"])
        if str(in_ncbi.loc[0, "Strand"]) == "+":
            strand = "1"
        elif str(in_ncbi.loc[0, "Strand"]) == "-":
            strand = "2"
        gene_list.loc[len(gene_list)] = [name, start, stop, strand]
    else:
        print(file+" is not in NCBI")

gene_list
# Out:
#                  accession      start       stop strand
# 0              NC_011283.1  1769523.0  1770404.0      2
# 1              NC_017174.1    1894823    1895572      1
# 2     NZ_JAEEGC010000032.1      27209      27979      1
# 3     NZ_JAHLQL010000001.1    1591380    1592219      2
# 4     NZ_JAHLQK010000001.1     563737     564495      1
# ...                    ...        ...        ...    ...
# 3922            DQ284983.1          1        800      1
# 3923            AY603652.1          1        580      1
# 3924            AJ302315.1          1        863      1
# 3925              U66032.1       4945       5643      1
# 3926              U23648.1          1        327      1
#
# [3927 rows x 4 columns]

# %% [markdown]
# ##  3 V2

# %%
# import pandas as pd
# import numpy as np


# gene_list = pd.DataFrame(columns=["accession", "start", "stop", "strand"])

# for name in seq_id:
#     file = "ipg_report/ipg_"+name+".txt"
#     ipg = pd.read_csv(file, sep="\t")

#     insdc = np.array(ipg.loc[:, "Source"] == "INSDC", dtype="bool")
#     refseq = np.array(ipg.loc[:, "Source"] == "RefSeq", dtype="bool")

#     in_ncbi = ipg.loc[refseq | insdc, :]
#     in_ncbi = in_ncbi.reset_index()
#     url = str()
#     if len(in_ncbi) != 0:
#         name = str(in_ncbi.loc[0, "Nucleotide Accession"])
#         start = str(in_ncbi.loc[0, "Start"])
#         stop = str(in_ncbi.loc[0, "Stop"])
#         if str(in_ncbi.loc[0, "Strand"]) == "+":
#             strand = "1"
#         elif str(in_ncbi.loc[0, "Strand"]) == "-":
#             strand = "2"
#         gene_list.loc[len(gene_list)] = [name, start, stop, strand]
#     else:
#         print(file+" is not in NCBI")

# gene_list

# %% [markdown]
# ## 4. Fetch with ENTREZ the INSDSeq XML report for each line of the previous table and download it (1h51min)

# %%
from Bio import Entrez

Entrez.email = "remi.legrand38@gmail.com.com"


def download_insdseq_xml(index):
    accession = gene_list.loc[index, "accession"]
    start = gene_list.loc[index, "start"]
    stop = gene_list.loc[index, "stop"]
    strand = gene_list.loc[index, "strand"]
    handle = Entrez.efetch(db='nucleotide', id=accession, rettype='gb',
                           retmode='xml', seq_start=start, seq_stop=stop, strand=strand)
    # Save the XML data to a file
    with open(f'insdseq_xml_report/{accession}_INSDSeq.xml', 'wb') as file:
        file.write(handle.read())

    print('INSDSeq XML report downloaded successfully.')


for i in range(len(gene_list)):
    download_insdseq_xml(i)
# Out:
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# ...
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.
# INSDSeq XML report downloaded successfully.

# %% [markdown]
# ## 5. Make a FASTA file by extracting for each file the taxa and the seq (25 sec)
# some files like NC_007512.1_INSDSeq.xml have a missing either sequence or taxomnomy: fixed with Try but i this case, it would be nice to search for an other sequence in the sequence list

# %%
import os
import xml.etree.ElementTree as ET

files = os.listdir('insdseq_xml_report')

with open('reference_db_ipg.fasta', 'w') as file:
    for xml_file in files:
        path = 'insdseq_xml_report/' + xml_file
        # print(path)
        tree = ET.parse(path)
        root = tree.getroot()
        try:
            tax = root.find("./GBSeq/GBSeq_taxonomy").text
            seq = root.find("./GBSeq/GBSeq_sequence").text
        except AttributeError:
            print("in", path, "sequence or taxonomy not found")
        # print(tax)
        # print(seq)
        file.write(">" + tax + "\n")
        file.write(seq + "\n")
# Out:
# in insdseq_xml_report/NC_007512.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NZ_JACDUL010000003.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NZ_ATNG01000008.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_014658.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_014002.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_002678.2_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_003901.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_005791.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_003030.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_007778.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_009434.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_011565.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NZ_CM001436.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_009937.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_009051.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_014408.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NZ_CP079862.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_010125.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_000909.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_004463.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NZ_BBEF01000051.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_006526.2_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_019943.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_010424.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_007413.1_INSDSeq.xml sequence or taxonomy not found
# in insdseq_xml_report/NC_003037.1_INSDSeq.xml sequence or taxonomy not found

# %% [markdown]
# files with problems on the first half of the document(sequence too long):
#
# insdseq_xml_report/NZ_JAGGMU010000001.1_INSDSeq.xml
# insdseq_xml_report/NC_008576.1_INSDSeq.xml
# insdseq_xml_report/NC_007681.1_INSDSeq.xml
# insdseq_xml_report/NC_018227.2_INSDSeq.xml
# insdseq_xml_report/J05111.1_INSDSeq.xml **contain nifU, nifS, nifB, nifH, etc**
# insdseq_xml_report/NC_016617.1_INSDSeq.xml
# insdseq_xml_report/NC_009523.1_INSDSeq.xml
# insdseq_xml_report/NC_014323.1_INSDSeq.xml
# insdseq_xml_report/CP003083.1_INSDSeq.xml
# insdseq_xml_report/NZ_JMIY01000005.1_INSDSeq.xml
# insdseq_xml_report/NC_011206.1_INSDSeq.xml
# insdseq_xml_report/NC_004041.2_INSDSeq.xml
# insdseq_xml_report/CP003284.1_INSDSeq.xml
# insdseq_xml_report/NC_009253.1_INSDSeq.xml
# insdseq_xml_report/NC_000916.1_INSDSeq.xml
# insdseq_xml_report/NC_011283.1_INSDSeq.xml

# %% [markdown]
# ## 6. Normalize the taxonomy (If I have the time): remove the sub classes
